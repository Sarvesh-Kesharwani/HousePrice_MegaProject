# %%
import pandas as pd
pd.set_option('display.max_columns', None)

data = pd.read_csv(r'..\3. eda_n_feature engineering\5.1 FEed furnishDetails col.csv')
data.head(3)
# Out:
#                                    property_name        sector  \
# 0                2 BHK Flat in Sector 70 Gurgaon    sector 70
# 1  3 Bedroom House for sale in Sector 40 Gurgaon    sector 40
# 2        5 Bedroom House for sale in Palam Vihar   palam vihar
#
#                    society  price_in_crores  price_per_sqft  bedRoom  \
# 0  shree vardhman victoria             1.10          8461.0      2.0
# 1                      NaN             2.15         23889.0      3.0
# 2       ansals palam vihar             9.00         19231.0      5.0
#
#    bathroom balcony                                 address  floorNum  \
# 0       2.0       2     Sector 70 Gurgaon, Gurgaon, Haryana       8.0
# 1       3.0       3     Sector 40 Gurgaon, Gurgaon, Haryana       0.0
# 2       5.0       2  J-Block, Palam Vihar, Gurgaon, Haryana       0.0
#
#        facing             agePossession  \
# 0  north-east  Very Recent Construction
# 1         NaN       Recent Construction
# ...

# %% [markdown]
# ### Temporarily removing non_numeric features

# %%
data.head(1)
# Out:
#                      property_name       sector                  society  \
# 0  2 BHK Flat in Sector 70 Gurgaon   sector 70   shree vardhman victoria
#
#    price_in_crores  price_per_sqft  bedRoom  bathroom balcony  \
# 0              1.1          8461.0      2.0       2.0       2
#
#                                address  floorNum      facing  \
# 0  Sector 70 Gurgaon, Gurgaon, Haryana       8.0  north-east
#
#               agePossession  \
# 0  Very Recent Construction
#
#                                      nearbyLocations  \
# 0  ['Airia Mall', 'Golf Course Extn Road', 'Sohna...
#
#                                          description  \
# 0  Square yards rera reg.\r\nHrera 660/2017/307\r...
#
#                                             features  \
# 0  ['Security / Fire Alarm', 'Power Back-up', 'Fe...
#
#                                               rating property_type  noOfFloor  \
# 0  ['Green Area5 out of 5', 'Construction5 out of...          flat        1.0
#
# ...

# %%
data.drop(['sector', 'property_name', 'society', 'bedRoom',	'bathroom',	'balcony','address', 'facing', 'agePossession', 'nearbyLocations', 'description', 'features', 'rating'], axis=1, inplace=True)

# %%
data['property_type'] = data['property_type'].apply(lambda x: 1 if 'f' in x else 0)

# %%
data.sample(1)
# Out:
#       price_in_crores  price_per_sqft  floorNum  property_type  noOfFloor  \
# 1961              1.7         17980.0       0.0              0        3.0
#
#       SuperBuiltupArea_sqft  BuiltupArea_sqft  CarpetArea_sqft  servantRoom  \
# 1961                    NaN            8100.0              NaN         True
#
#       studyRoom  poojaRoom  storeRoom  otherAdditionalRoom  luxury_class
# 1961      False      False       True                False             0

# %% [markdown]
# ### Modeling

# %%
x = data.drop(['price_in_crores'], axis=1)
y = data['price_in_crores'].fillna(0)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.2, random_state=42)
rfr = RandomForestRegressor()
rfr.fit(train_x, train_y)
# Out:
# RandomForestRegressor()

# %%
test_y_pred = rfr.predict(test_x)

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(test_y, test_y_pred)
# Out:
# 0.3692359748427674

# %%
import pickle 
pickle.dump(rfr, open(r'model.pkl', 'wb'))

# %% [markdown]
# ### Exporting Final Data

# %%
data.to_csv(r'final_data.csv')
