# %%
from dotenv import load_dotenv
load_dotenv()
import os

root_dir = os.environ['PROJECT_ROOT']
print(root_dir)
# Out:
# F:\Github_dsc\HousePrice_MegaProject

# %%
print(root_dir+'/1. data_gathering\data')
# Out:
# F:\Github_dsc\HousePrice_MegaProject/1. data_gathering\data

# %%
import pandas as pd 
merged_df = pd.DataFrame()

folder_path=os.path.join(root_dir, '1. data_gathering\data')
all_files = os.listdir(folder_path)
csv_files = [file for file in all_files if file.endswith('.csv')]

dfs = [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files]
merged_df = pd.concat(dfs, ignore_index=True)
merged_df.shape
# Out:
# (150, 25)

# %%
merged_df.sample(5)
# Out:
#      Unnamed: 0       society_name            property_title   property_rent  \
# 135          10     Apollo DB City       3 BHK Flat for rent  ₹35,200 /month
# 131           6     Premier Towers       3 BHK Flat for rent  ₹40,500 /month
# 54            4  Signature Heights       2 BHK Flat for rent  ₹18,000 /month
# 50            0  Jiyo Samarth Park  3 Bedroom House for rent  ₹18,000 /month
# 15           15     Premier Towers       2 BHK Flat for rent  ₹25,000 /month
#
#      types_of_rooms_available  furnishing_details_lst bedroom_count  \
# 135                       NaN                     NaN    3 Bedrooms
# 131                       NaN                     NaN    3 Bedrooms
# 54                        NaN                     NaN    2 Bedrooms
# 50                        NaN                     NaN    3 Bedrooms
# 15                        NaN                     NaN    2 Bedrooms
#
#     bathroom_count balcony_count  superBuiltUp_area_sqft  ...  \
# 135    2 Bathrooms   2 Balconies                  1982.0  ...
# 131    3 Bathrooms     1 Balcony                     NaN  ...
# 54     2 Bathrooms     1 Balcony                     NaN  ...
# 50     4 Bathrooms     1 Balcony                     NaN  ...
# 15     2 Bathrooms   2 Balconies                  1000.0  ...
#
#            Posted_By_and_On   Flooring        Floor_Number  Power_Backup  \
# 135  Dealer on May 08, 2024     Marble  5th   of 13 Floors       Partial
# 131  Dealer on May 08, 2024     Marble  6th   of 12 Floors          Full
# 54    Owner on Jul 01, 2024    Ceramic  9th   of 10 Floors       Partial
# 50    Owner on Jul 01, 2024        NaN                 NaN           NaN
# 15   Dealer on Jul 02, 2024  Vitrified   2nd   of 6 Floors           NaN
#
#            Property_Age Months_of_Notice Gated_Community  \
# 135    5 to 10 Year Old         1 Months             Yes
# 131     1 to 5 Year Old         1 Months             Yes
# 54   Under Construction         1 Months             Yes
# 50     5 to 10 Year Old         0 Months             NaN
# 15     5 to 10 Year Old         1 Months             Yes
#
#     Electricity_n_Water_Charges  \
# 135        Charges not included
# 131            Charges included
# 54             Charges included
# 50         Charges not included
# 15         Charges not included
#
#                                      property_features avg_rating
# 135  Centrally Air Conditioned\r\nWater purifier\r\...        4.1
# 131  Security / Fire Alarm\r\nFeng Shui / Vaastu Co...        4.0
# 54                                                 NaN        4.0
# 50   Feng Shui / Vaastu Compliant\r\nPrivate Garden...        4.1
# 15   Security / Fire Alarm\r\nFeng Shui / Vaastu Co...        4.0
#
# [5 rows x 25 columns]

# %%
merged_df.to_csv(os.path.join(root_dir, '1. data_gathering\data\mergeddata.csv'))
