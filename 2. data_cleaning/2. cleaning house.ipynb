# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

data = pd.read_csv(r'F:\Github_dsc\HousePrice_MegaProject\1. data_gathering\3. merging data\cx_data\1. manually cleaned data\independent-house - independent-house.csv')
data.sample(3)
# Out:
#                                       property_name  \
# 715         8 Bedroom House for sale in Malibu Town
# 1047  5 Bedroom House for sale in Sector 33 Gurgaon
# 723   5 Bedroom House for sale in Sector 14 Gurgaon
#
#                                                    link  \
# 715   https://www.99acres.com/8-bhk-bedroom-independ...
# 1047  https://www.99acres.com/5-bhk-bedroom-independ...
# 723   https://www.99acres.com/5-bhk-bedroom-independ...
#
#                        society       price             rate  \
# 715               Malibu Towne  8.81 Crore  ₹ 27,191/sq.ft.
# 1047  Unitech Uniworld Resorts   8.5 Crore  ₹ 17,820/sq.ft.
# 723                        NaN  4.15 Crore  ₹ 18,444/sq.ft.
#
#                        area                 areaWithType     bedRoom  \
# 715   (301 sq.m.) Plot Area  Plot area 360(301.01 sq.m.)  8 Bedrooms
# 1047  (443 sq.m.) Plot Area  Plot area 530(443.15 sq.m.)  5 Bedrooms
# 723   (209 sq.m.) Plot Area  Plot area 250(209.03 sq.m.)  5 Bedrooms
#
# ...

# %%
data.drop(columns=['link', 'property_id'], inplace=True)

# %%
data.sample(3)
# Out:
#                                        property_name             society  \
# 750  6 Bedroom House for sale in Sushant Lok Phase 3                 NaN
# 317         12 Bedroom House for sale in Malibu Town        Malibu Towne
# 518    5 Bedroom House for sale in Sector 11 Gurgaon  Sai Kripa Floors 5
#
#           price             rate                       area  \
# 750  6.21 Crore  ₹ 23,000/sq.ft.      (251 sq.m.) Plot Area
# 317   8.5 Crore  ₹ 53,125/sq.ft.  (149 sq.m.) Built-up Area
# 518      90 Lac  ₹ 11,250/sq.ft.       (74 sq.m.) Plot Area
#
#                            areaWithType      bedRoom      bathroom  \
# 750         Plot area 300(250.84 sq.m.)   6 Bedrooms   6 Bathrooms
# 317  Built Up area: 1600 (148.64 sq.m.)  12 Bedrooms  12 Bathrooms
# 518          Plot area 800(74.32 sq.m.)   5 Bedrooms   5 Bathrooms
#
#           balcony                                 additionalRoom  \
# 750  3+ Balconies  Store Room,Pooja Room,Study Room,Servant Room
# ...

# %% [markdown]
# # society col

# %%
data['society'].value_counts(dropna=False)
# Out:
# society
# NaN                                                  624
# Vipul Tatvam Villa                                    27
# Emaar MGF Marbella                                    26
# International City by SOBHA Phase 2                   26
# International City by Sobha Phase 1                   23
# Unitech Uniworld Resorts                              14
# DLF City Plots                                        11
# DLF City Plots Phase 2                                11
# Unitech Espace                                        11
# Bptp Visionnaire                                       9
# Eldeco Mansionz                                        9
# Uppal Southend4.0 ★                                    9
# Not Applicable                                         7
# Experion Windchants3.8 ★                               6
# Ansals Palam Vihar                                     6
# Sushant Lok 1 Builder Floors                           6
# ...

# %%
import regex as re
data['society'].str.lower().str.strip().astype(str).apply(lambda row: re.sub(r'\d+(\.\d+)?\s?★', '', row)).value_counts(dropna=False)
# Out:
# society
# nan                                                  624
# vipul tatvam villa                                    27
# emaar mgf marbella                                    26
# international city by sobha phase 2                   26
# international city by sobha phase 1                   23
# unitech uniworld resorts                              14
# dlf city plots                                        11
# dlf city plots phase 2                                11
# unitech espace                                        11
# bptp visionnaire                                       9
# eldeco mansionz                                        9
# uppal southend                                         9
# not applicable                                         7
# experion windchants                                    6
# ansals palam vihar                                     6
# sushant lok 1 builder floors                           6
# ...

# %%
data['society'] = data['society'].str.lower().str.strip().astype(str).apply(lambda row: re.sub(r'\d+(\.\d+)?\s?★', '', row))

# %%
data.sample(3)
# Out:
#                                       property_name  \
# 312     4 Bedroom House for sale in Sector-33 Sohna
# 205   9 Bedroom House for sale in Sector 9A Gurgaon
# 428  6 Bedroom House for sale in Sector 63A Gurgaon
#
#                         society      price             rate  \
# 312  central park flower valley        NaN              NaN
# 205                         nan  4.5 Crore  ₹ 14,286/sq.ft.
# 428           anant raj estates  8.5 Crore  ₹ 27,139/sq.ft.
#
#                           area                 areaWithType     bedRoom  \
# 312  (344 sq.m.) Built-up Area                          NaN         NaN
# 205      (293 sq.m.) Plot Area    Plot area 14(354.1 sq.m.)  9 Bedrooms
# 428      (291 sq.m.) Plot Area  Plot area 348(290.97 sq.m.)  6 Bedrooms
#
#         bathroom       balcony                additionalRoom  \
# 312          NaN           NaN                           NaN
# 205  9 Bathrooms  3+ Balconies  Pooja Room,Study Room,Others
# ...

# %%
data['price'].value_counts()
# Out:
# price
# 3.5 Crore           19
# 5.5 Crore           17
# 6.5 Crore           16
# 6 Crore             14
# 8 Crore             13
# 5 Crore             13
# 4.5 Crore           13
# 50 Lac              13
# 70 Lac              13
# 75 Lac              13
# 85 Lac              12
# 2.5 Crore           12
# 8.5 Crore           12
# 7 Crore             12
# 4 Crore             11
# 1.5 Crore           11
# 60 Lac              10
# 45 Lac              10
# Price on Request    10
# 90 Lac              10
# 10 Crore            10
# 9 Crore             10
# 2.25 Crore          10
# 80 Lac               9
# 1.7 Crore            9
# 9.5 Crore            9
# 1.1 Crore            9
# 12 Crore             9
# 2 Crore              9
# 1.6 Crore            8
# 4.6 Crore            8
# 1 Crore              8
# 6.75 Crore           8
# 11 Crore             8
# 3.75 Crore           8
# 1.2 Crore            7
# 2.1 Crore            7
# 1.3 Crore            7
# 65 Lac               7
# ...

# %%
def clean_price_col(row):
    if 'lac' in row:
        return round(float(row.split(' ')[0])/100, 2)
    elif 'crore' in row:
        return round(float(row.split(' ')[0]), 2)
    else:
        return row

data['price'] = data['price'].str.strip().str.lower().astype(str).apply(clean_price_col)

# %%
data['price'].value_counts(dropna=False)
# Out:
# price
# nan                 127
# 3.5                  19
# 5.5                  17
# 6.5                  16
# 6.0                  14
# 8.0                  13
# 5.0                  13
# 4.5                  13
# 0.75                 13
# 0.5                  13
# 0.7                  13
# 7.0                  12
# 2.5                  12
# 0.85                 12
# 8.5                  12
# 1.5                  11
# 0.6                  11
# 4.0                  11
# 9.0                  10
# 0.9                  10
# price on request     10
# 2.25                 10
# 10.0                 10
# 0.45                 10
# 9.5                   9
# 0.8                   9
# 1.1                   9
# 1.7                   9
# 12.0                  9
# 2.0                   9
# 0.55                  8
# 1.0                   8
# 11.0                  8
# 6.75                  8
# 3.75                  8
# 1.6                   8
# 4.6                   8
# 2.1                   7
# ...

# %%
data['price'].value_counts()
# Out:
# price
# nan      127
# 3.5       19
# 5.5       17
# 6.5       16
# 6.0       14
# 5.0       13
# 4.5       13
# 8.0       13
# 0.7       13
# 0.5       13
# 0.75      13
# 7.0       12
# 8.5       12
# 0.85      12
# 2.5       12
# 0.6       11
# 1.5       11
# 4.0       11
# 10.0      10
# 0.9       10
# 9.0       10
# 2.25      10
# 0.45      10
# 0.8        9
# 12.0       9
# 2.0        9
# 1.1        9
# 1.7        9
# 9.5        9
# 0.55       8
# 3.75       8
# 1.6        8
# 4.6        8
# 11.0       8
# 6.75       8
# 1.0        8
# 1.35       7
# 12.5       7
# 0.95       7
# 0.65       7
# 1.2        7
# 1.3        7
# 2.1        7
# 0.4        7
# 5.6        6
# 1.15       6
# 10.5       6
# 7.5        6
# 3.6        6
# 16.0       6
# 3.25       6
# 4.25       6
# 2.95       6
# 13.5       6
# 1.45       6
# 6.25       6
# 7.25       6
# 2.75       6
# 5.7        6
# 0.38       5
# 8.25       5
# 15.0       5
# 3.0        5
# 4.75       5
# 5.75       5
# 0.35       5
# ...

# %%
data = data[data['price']!='price on request']

# %%
data.sample(3)
# Out:
#                                       property_name  \
# 105   4 Bedroom House for sale in Sector 48 Gurgaon
# 75   5 Bedroom House for sale in Sector 109 Gurgaon
# 838     8 Bedroom House for sale in Uppals Southend
#
#                                  society price             rate  \
# 105                   vipul tatvam villa   nan  ₹ 18,750/sq.ft.
# 75   international city by sobha phase 2   nan  ₹ 13,622/sq.ft.
# 838                                  nan   4.5  ₹ 15,625/sq.ft.
#
#                               area                 areaWithType     bedRoom  \
# 105  (372-441 sq.m.) Built-up Area                          NaN         NaN
# 75   (467-681 sq.m.) Built-up Area                          NaN         NaN
# 838          (268 sq.m.) Plot Area  Plot area 320(267.56 sq.m.)  8 Bedrooms
#
#         bathroom      balcony                                 additionalRoom  \
# 105          NaN          NaN                                            NaN
# ...
