# %% [markdown]
# ### loading dataset

# %%
import pandas as pd
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv(r'..\2. data_cleaning\3.1 merged_flat_house_data.csv')
data.drop(columns=['Unnamed: 0'], axis=1, inplace=True)
data.sample(3)
# Out:
#                                      property_name          society  \
# 453                3 BHK Flat in Sector 69 Gurgaon     tulip violet
# 787  3 Bedroom House for sale in Sector 43 Gurgaon   landmark house
# 921               2 BHK Flat in Sector 108 Gurgaon  raheja vedaanta
#
#      area_in_sqft  price_in_crores  price_per_sqft  \
# 453        1850.0             1.76          9513.0
# 787        1080.0             2.75         25463.0
# 921        1500.0             0.70          4666.0
#
#                                           areaWithType  bedRoom  bathroom  \
# 453             Super Built up area 1850(171.87 sq.m.)      3.0       4.0
# 787                        Plot area 120(100.34 sq.m.)      3.0       3.0
# 921  Built Up area: 1468 (136.38 sq.m.)Carpet area:...      2.0       2.0
#
#     balcony additionalRoom                                            address  \
# 453       2  not available           004, Sector 69 Gurgaon, Gurgaon, Haryana
# 787       1     Pooja Room  1251, C Block, Sushant Lok, Gurugram, Haryana ...
# 921       1  not available   Sector 108, Sector 108 Gurgaon, Gurgaon, Haryana
#
#      floorNum      facing     agePossession  \
# 453       0.0  south-west   1 to 5 Year Old
# 787       0.0  south-east  5 to 10 year old
# 921      10.0        west  5 to 10 Year Old
#
#                                        nearbyLocations  \
# 453  ['Airia Mall Sector 68', 'Southern Peripheral ...
# 787  ['Sector 42-43 metro station', 'Huda city cent...
# 921                                                NaN
#
#                                            description  \
# 453  Ground floor 1850 sqft this 3 bhk flat is loca...
# 787  It is designer duplex house with a double heig...
# 921  2 bath, semi furnished, 10th floor (Of 16), ov...
#
#                                         furnishDetails  \
# 453  ['1 Modular Kitchen', 'No AC', 'No Bed', 'No C...
# 787                                                NaN
# 921                                                NaN
#
#                                               features  \
# 453  ['Water purifier', 'Security / Fire Alarm', 'P...
# 787  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 921                                                NaN
#
#                                                 rating property_type  \
# 453  ['Green Area5 out of 5', 'Construction4 out of...          flat
# 787  ['Environment4 out of 5', 'Lifestyle4 out of 5...         house
# 921  ['Green Area4 out of 5', 'Amenities4 out of 5'...          flat
#
#      noOfFloor                   area
# 453        1.0                    NaN
# 787        2.0  (100 sq.m.) Plot Area
# 921        1.0                    NaN

# %% [markdown]
# ### FEing `property_name` col

# %% [markdown]
# #### creating `sector` col from property_name col

# %%
data.head(3)
# Out:
#                                    property_name                  society  \
# 0                2 BHK Flat in Sector 70 Gurgaon  shree vardhman victoria
# 1  3 Bedroom House for sale in Sector 40 Gurgaon                      NaN
# 2        5 Bedroom House for sale in Palam Vihar       ansals palam vihar
#
#    area_in_sqft  price_in_crores  price_per_sqft  \
# 0        1300.0             1.10          8461.0
# 1         900.0             2.15         23889.0
# 2        4680.0             9.00         19231.0
#
#                        areaWithType  bedRoom  bathroom balcony  \
# 0  Carpet area: 1300 (120.77 sq.m.)      2.0       2.0       2
# 1        Plot area 100(83.61 sq.m.)      3.0       3.0       3
# 2       Plot area 520(434.79 sq.m.)      5.0       5.0       2
#
#                                   additionalRoom  \
# 0                                  not available
# 1               Pooja Room,Study Room,Store Room
# 2  Pooja Room,Study Room,Servant Room,Store Room
#
#                                   address  floorNum      facing  \
# 0     Sector 70 Gurgaon, Gurgaon, Haryana       8.0  north-east
# 1     Sector 40 Gurgaon, Gurgaon, Haryana       0.0         NaN
# 2  J-Block, Palam Vihar, Gurgaon, Haryana       0.0       north
#
#       agePossession                                    nearbyLocations  \
# 0   1 to 5 Year Old  ['Airia Mall', 'Golf Course Extn Road', 'Sohna...
# 1  5 to 10 year old  ['Huda city centre metro station', 'Axis bank ...
# 2      10+ year old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
#
#                                          description  \
# 0  Square yards rera reg.\r\nHrera 660/2017/307\r...
# 1  Its just behind ryan international school and ...
# 2  North facing plot aviable on sale in palam vih...
#
#                                       furnishDetails  \
# 0  ['3 Wardrobe', '1 Modular Kitchen', '1 Chimney...
# 1  ['4 Wardrobe', '5 Fan', '4 Geyser', '2 Light',...
# 2  ['1 Water Purifier', '4 Fan', '1 Fridge', '1 E...
#
#                                             features  \
# 0  ['Security / Fire Alarm', 'Power Back-up', 'Fe...
# 1  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 2  ['Feng Shui / Vaastu Compliant', 'Private Gard...
#
#                                               rating property_type  noOfFloor  \
# 0  ['Green Area5 out of 5', 'Construction5 out of...          flat        1.0
# 1  ['Environment4 out of 5', 'Lifestyle4 out of 5...         house        3.0
# 2  ['Environment5 out of 5', 'Safety4 out of 5', ...         house        2.0
#
#                     area
# 0                    NaN
# 1   (84 sq.m.) Plot Area
# 2  (435 sq.m.) Plot Area

# %%
data['property_name']
# Out:
# 0                        2 BHK Flat in Sector 70 Gurgaon
# 1          3 Bedroom House for sale in Sector 40 Gurgaon
# 2                5 Bedroom House for sale in Palam Vihar
# 3                        4 BHK Flat in Sector 69 Gurgaon
# 4                              4 BHK Flat in New Gurgaon
#                               ...
# 4077    16 Bedroom House for sale in Sushant Lok Phase 2
# 4078                           3 BHK Flat in Palam Vihar
# 4079                     3 BHK Flat in Sector 59 Gurgaon
# 4080                       3 BHK Flat in Sector 36 Sohna
# 4081                     4 BHK Flat in Sector 15 Gurgaon
# Name: property_name, Length: 4082, dtype: object

# %%
data.insert(loc=1, column='sector', value=data['property_name'].str.lower().str.strip().str.split('in').str[1].str.replace('gurgaon', ''))

# %%
data.sample(3)
# Out:
#                         property_name        sector  \
# 372         3 BHK Flat in DLF Phase 5   dlf phase 5
# 3826  3 BHK Flat in Sector 69 Gurgaon    sector 69
# 1447  4 BHK Flat in Sector 82 Gurgaon    sector 82
#
#                         society  area_in_sqft  price_in_crores  \
# 372          dlf carlton estate        1407.0             2.00
# 3826               tulip violet        1570.0             1.40
# 1447  vatika independent floors        1800.0             1.45
#
#       price_per_sqft                            areaWithType  bedRoom  \
# 372          14214.0  Super Built up area 1407(130.71 sq.m.)      3.0
# 3826          8920.0  Super Built up area 1568(145.67 sq.m.)      3.0
# 1447          8056.0      Built Up area: 1800 (167.23 sq.m.)      4.0
#
#       bathroom balcony additionalRoom  \
# 372        3.0       2  not available
# 3826       3.0       1     pooja room
# 1447       3.0       0  not available
#
#                                               address  floorNum      facing  \
# 372                     DLF Phase 5, Gurgaon, Haryana       5.0  south-west
# 3826  12th Floor, Sector 69 Gurgaon, Gurgaon, Haryana      12.0        east
# 1447   Sector 82, Sector 82 Gurgaon, Gurgaon, Haryana       1.0         NaN
#
#          agePossession                                    nearbyLocations  \
# 372   5 to 10 Year Old  ['Sector 53-54', 'South Point Mall', 'United C...
# 3826   1 to 5 Year Old  ['Airia Mall Sector 68', 'Southern Peripheral ...
# 1447         undefined  ['Sapphire 83 Mall', 'Delhi Jaipur Expressway'...
#
#                                             description  \
# 372   This is your chance to own a 3 bhk residential...
# 3826  Looking for a 3 bhk property for sale in gurga...
# 1447  Multistorey apartment is available for sale. I...
#
#                                          furnishDetails  \
# 372   ['2 Wardrobe', '1 Sofa', '2 Geyser', '2 AC', '...
# 3826  ['1 Modular Kitchen', 'No AC', 'No Bed', 'No C...
# 1447  ['1 Wardrobe', '1 Fan', '1 Light', 'No AC', 'N...
#
#                                                features  \
# 372   ['Feng Shui / Vaastu Compliant', 'Intercom Fac...
# 3826  ['Power Back-up', 'Feng Shui / Vaastu Complian...
# 1447                                                NaN
#
#                                                  rating property_type  \
# 372   ['Green Area5 out of 5', 'Construction4.5 out ...          flat
# 3826  ['Green Area5 out of 5', 'Construction4 out of...          flat
# 1447  ['Green Area5 out of 5', 'Construction4 out of...          flat
#
#       noOfFloor area
# 372         1.0  NaN
# 3826        1.0  NaN
# 1447        1.0  NaN

# %% [markdown]
# #### observation:
# #####  now new col `sector` somewhere contains sector number like `sector 69` and somewhere sector names like `dlf phase 5`

# %% [markdown]
# ##### now let's check if proprty_name col really didn't contain sectorNum for the rows our code couldn't extract sectorNum

# %%
data[data['sector'].apply(lambda x: 'sector' not in str(x))]['property_name'].value_counts()
# Out:
# property_name
# 2 BHK Flat in Sohna                                 125
# 3 BHK Flat in Nirvana Country                        20
# 3 BHK Flat in Sohna                                  20
# 5 Bedroom House for sale in DLF Phase 1              16
# 5 Bedroom House for sale in DLF Phase 2              16
#                                                    ...
# 16 Bedroom House for sale in Sushant Lok Phase 1      1
# 5 Bedroom House for sale in Surya Vihar               1
# 2 Bedroom House for sale in Bhawani Enclave           1
# 3 BHK Flat in Sultanpur                               1
# 16 Bedroom House for sale in Sushant Lok Phase 2      1
# Name: count, Length: 445, dtype: int64

# %%
data[data['sector'].apply(lambda x: 'sector' not in str(x))]['sector'].value_counts()
# Out:
# sector
#  sohna                         164
#  nirvana country                54
#  palam vihar                    52
#  dlf phase 1                    46
#  dlf phase 2                    44
#                               ...
#  g block dlf city phase 1        1
#  bhora kalan                     1
#  ashok vihar phase 3             1
#  ats marigold                    1
#  jacobpura near sadar bazar      1
# Name: count, Length: 163, dtype: int64

# %% [markdown]
# ##### checking values in sector col which do not cotain sectorNum

# %%
data[data['sector'].apply(lambda x: 'sector' not in str(x))]['sector'].unique()
# Out:
# array([' palam vihar', ' new ', ' dayanand colony', ' acharya puri',
#        ' bhora kalan', ' dlf phase 4', ' sohna', ' nirvana country',
#        ' rajendra park', ' greenwood city', ' near euro ',
#        ' rattan garden', ' manesar', ' dlf phase 5', ' shanti nagar',
#        ' saraswati vihar', ' dlf phase 1', ' sushant lok phase 1',
#        ' dlf phase 2', ' sohna road', ' gwal pahari', ' dharam colony',
#        ' laxman vihar', ' saraswati enclave', ' golf course road',
#        ' civil l', ' malibu town', ' om nagar', ' dlf phase 3',
#        ' new basti', ' kheri', ' maruti kunj', ' adarsh nagar',
#        ' subhash nagar', ' madanpuri', ' daulatabad', ' samaspur',
#        ' jacobpura', ' new colony', ' dwarka expressway ',
#        ' new palam vihar', ' south city 1',
#        ' b block sushant lok phase 1', ' sohna  road', ' hira nagar',
#        ' sheetla colony', ' bhim nagar', ' jyoti park', ' surya vihar',
#        ' , delhi ncr', ' mianwali colony', ' ashok vihar phase 2',
#        ' surat nagar phase 2', ' shivaji nagar',
#        ' jat colony,fazilpur/taj nagar road', ' mohan nagar',
#        ' gandhi nagar', ' c block sushant lok phase 1', ' rajiv nagar',
#        ' shivpuri', ' park view', ' sushant lok phase 3', ' bhondsi',
#        ' sushant lok phase 2', ' laxmna vihar, phase 2',
#        ' palam vihar extension', ' mehrauli  road', ' uppals southend',
#        ' heritage city', ' dhunela', ' saroop garden rajendra park',
#        ' mayfield garden', ' surat nagar 1', ' prem nagar', ' vir nagar',
#        ' krishna colony', ' arjun nagar', ' laxman vihar phase 2',
#        ' ashok vihar phase 3 extension', ' sushant lok', ' suncity',
#        ' baldev nagar', ' west rajiv nagar', ' carterpuri village',
#        ' devi lal colony gali no 12  nr omkar public school',
#        ' v block dlf phase 3', ' dhankot', " ansal's palam vihar",
#        ' lajpat nagar', ' garhi harsaru', ' ansal plaza', ' ats marigold',
#        ' bissar', ' ashok vihar phase 3', ' chakkarpur', ' shankar vihar',
#        ' g block dlf city phase 1', ' patel nagar',
#        ' bhimgarh kheri phase 3', ' imt manesar', ' kanahi',
#        ' heera nagar', ' sultanpur', ' bhawani enclave',
#        ' a block sushant lok phase 1', ' begampur khatola',
#        ' udyog vihar phase 1', ' mg road', ' devilal colony',
#        ' ashok vihar', '  faridabad road', ' sispal vihar',
#        ' surat nagar', ' ashok vihar phase i', ' garauli kalan',
#        ' rajiv colony', ' block a surya vihar', ' vishnu garden', ' nars',
#        ' naharpur rupa', ' bptp', ' golf course ext road',
#        ' new palam vihar phase 2',
#        ' sec 3 bhim vihar part 1 bhimgher kheri', ' laxmi garden',
#        ' manohar nagar', ' farukhnagar', ' cyber city', ' ghamroj',
#        ' nirvana country pocket h', ' iffco chowk', ' tekchand nagar',
#        ' sai kunj', ' sadar bazar', ' shakti nagar', ' near khandsa road',
#        ' block h ashok vihar phase iii extension', ' shivji park colony',
#        ' ravi nagar', ' pratap nagar', ' ram nagar',
#        ' near nand hospital', ' new palam vihar phase 1', ' lucknow',
#        ' khandsa', ' rajiv chowk', ' hno 13 sagar enclave sura',
#        ' rosewood', ' huda saraswati vihar', ' alipur',
#        ' valley view estate', ' mahavir pura', ' pataudi road',
#        ' laxman vihar, railway road,', ' near pataudi chowk',
#        ' gopal nagar, garhi ghasita, sonipat', ' ravi nager basai road',
#        ' damdma', ' ambience island', ' mahalaxmi garden, rajendra place',
#        ' south city', ' new jyoti park', ' jacobpura near sadar bazar'],
#       dtype=object)

# %%
len(data[data['sector'].apply(lambda x: 'sector' not in str(x))]['sector'].unique())
# Out:
# 163

# %% [markdown]
# ##### using chatgpt to get sector_numbers for sector_names in our sector col

# %%
data.head(3)
# Out:
#                                    property_name        sector  \
# 0                2 BHK Flat in Sector 70 Gurgaon    sector 70
# 1  3 Bedroom House for sale in Sector 40 Gurgaon    sector 40
# 2        5 Bedroom House for sale in Palam Vihar   palam vihar
#
#                    society  area_in_sqft  price_in_crores  price_per_sqft  \
# 0  shree vardhman victoria        1300.0             1.10          8461.0
# 1                      NaN         900.0             2.15         23889.0
# 2       ansals palam vihar        4680.0             9.00         19231.0
#
#                        areaWithType  bedRoom  bathroom balcony  ...  \
# 0  Carpet area: 1300 (120.77 sq.m.)      2.0       2.0       2  ...
# 1        Plot area 100(83.61 sq.m.)      3.0       3.0       3  ...
# 2       Plot area 520(434.79 sq.m.)      5.0       5.0       2  ...
#
#        facing     agePossession  \
# 0  north-east   1 to 5 Year Old
# 1         NaN  5 to 10 year old
# 2       north      10+ year old
#
#                                      nearbyLocations  \
# 0  ['Airia Mall', 'Golf Course Extn Road', 'Sohna...
# 1  ['Huda city centre metro station', 'Axis bank ...
# 2  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
#
#                                          description  \
# 0  Square yards rera reg.\r\nHrera 660/2017/307\r...
# 1  Its just behind ryan international school and ...
# 2  North facing plot aviable on sale in palam vih...
#
#                                       furnishDetails  \
# 0  ['3 Wardrobe', '1 Modular Kitchen', '1 Chimney...
# 1  ['4 Wardrobe', '5 Fan', '4 Geyser', '2 Light',...
# 2  ['1 Water Purifier', '4 Fan', '1 Fridge', '1 E...
#
#                                             features  \
# 0  ['Security / Fire Alarm', 'Power Back-up', 'Fe...
# 1  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 2  ['Feng Shui / Vaastu Compliant', 'Private Gard...
#
#                                               rating property_type noOfFloor  \
# 0  ['Green Area5 out of 5', 'Construction5 out of...          flat       1.0
# 1  ['Environment4 out of 5', 'Lifestyle4 out of 5...         house       3.0
# 2  ['Environment5 out of 5', 'Safety4 out of 5', ...         house       2.0
#
#                     area
# 0                    NaN
# 1   (84 sq.m.) Plot Area
# 2  (435 sq.m.) Plot Area
#
# [3 rows x 23 columns]

# %%
sector_gpt = {
    'palam vihar': 'Sector 22, 23',
    'new': 'New Gurgaon spans multiple sectors: 76-95',
    'dayanand colony': 'Sector 6',
    'acharya puri': 'Sector 12A',
    'bhora kalan': 'Near Manesar',
    'dlf phase 4': 'Sector 28, 43',
    'sohna': 'Sohna (not in sectors)',
    'nirvana country': 'Sector 50, 51',
    'rajendra park': 'Sector 105',
    'greenwood city': 'Sector 45, 46',
    'near euro': 'No specific sector identified',
    'rattan garden': 'Sector 7',
    'manesar': 'Sector 1, 3, 5, 7',
    'dlf phase 5': 'Sector 43, 53, 54',
    'shanti nagar': 'Sector 11',
    'saraswati vihar': 'Sector 28, 43',
    'dlf phase 1': 'Sector 26, 28',
    'sushant lok phase 1': 'Sector 27, 28, 43',
    'dlf phase 2': 'Sector 25, 25A',
    'sohna road': 'Spans multiple sectors along the road',
    'gwal pahari': 'Sector 2, Gurugram-Faridabad Road',
    'dharam colony': 'Sector 11',
    'laxman vihar': 'Sector 3',
    'saraswati enclave': 'Sector 10A',
    'golf course road': 'Spans multiple sectors along the road',
    'civil': 'Assumed to be Civil Lines, near Sector 12',
    'malibu town': 'Sector 47',
    'om nagar': 'Sector 14',
    'dlf phase 3': 'Sector 24, 25A',
    'new basti': 'No specific sector identified',
    'kheri': 'Near Sector 37',
    'maruti kunj': 'Sector 37',
    'adarsh nagar': 'Sector 12',
    'subhash nagar': 'Sector 12',
    'madanpuri': 'Sector 7',
    'daulatabad': 'Near Sector 104',
    'samaspur': 'Sector 51',
    'jacobpura': 'Sector 12',
    'new colony': 'Sector 7',
    'dwarka expressway': 'Spans multiple sectors along the expressway',
    'new palam vihar': 'Sector 110, 111',
    'south city 1': 'Sector 30, 40, 41',
    'b block sushant lok phase 1': 'Sector 43',
    'sohna road': 'Spans multiple sectors along the road',
    'hira nagar': 'Sector 9',
    'sheetla colony': 'Sector 5',
    'bhim nagar': 'Sector 6',
    'jyoti park': 'Sector 7',
    'surya vihar': 'Sector 9',
    ', delhi ncr': 'Not in Gurgaon sectors',
    'mianwali colony': 'Sector 12',
    'ashok vihar phase 2': 'Sector 5',
    'surat nagar phase 2': 'Sector 104',
    'shivaji nagar': 'Sector 7',
    'jat colony, fazilpur/taj nagar road': 'Near Sector 37',
    'mohan nagar': 'Sector 6',
    'gandhi nagar': 'Sector 11',
    'c block sushant lok phase 1': 'Sector 43',
    'rajiv nagar': 'Sector 13',
    'shivpuri': 'Sector 7',
    'park view': 'Sector 61',
    'sushant lok phase 3': 'Sector 57',
    'bhondsi': 'Sohna Road, Near Sector 67',
    'sushant lok phase 2': 'Sector 55, 56',
    'laxman vihar, phase 2': 'Sector 3',
    'palam vihar extension': 'Sector 22, 23',
    'mehrauli road': 'Spans multiple sectors along the road',
    'uppals southend': 'Sector 49',
    'heritage city': 'Sector 25A',
    'dhunela': 'Sohna Road, Near Sector 68',
    'saroop garden rajendra park': 'Sector 105',
    'mayfield garden': 'Sector 50, 51',
    'surat nagar 1': 'Sector 104',
    'prem nagar': 'Sector 12',
    'vir nagar': 'Sector 5',
    'krishna colony': 'Sector 7',
    'arjun nagar': 'Sector 8',
    'laxman vihar phase 2': 'Sector 3',
    'ashok vihar phase 3 extension': 'Sector 5',
    'sushant lok': 'Sector 27, 28, 43',
    'suncity': 'Sector 54',
    'baldev nagar': 'Sector 7',
    'west rajiv nagar': 'Sector 13',
    'carterpuri village': 'Sector 23',
    'devi lal colony gali no 12 nr omkar public school': 'Sector 9',
    'v block dlf phase 3': 'Sector 24, 25A',
    'dhankot': 'Near Sector 102',
    "ansal's palam vihar": 'Sector 22, 23',
    'lajpat nagar': 'Sector 4',
    'garhi harsaru': 'Near Sector 104',
    'ansal plaza': 'Sector 23',
    'ats marigold': 'Sector 89A',
    'bissar': 'Near Sector 37',
    'ashok vihar phase 3': 'Sector 5',
    'chakkarpur': 'Sector 28',
    'shankar vihar': 'Sector 9',
    'g block dlf city phase 1': 'Sector 26, 28',
    'patel nagar': 'Sector 15',
    'bhimgarh kheri phase 3': 'Sector 9',
    'imt manesar': 'Sector 1, 3, 5, 7',
    'kanahi': 'Sector 44',
    'heera nagar': 'Sector 9',
    'sultanpur': 'Near Sector 99A',
    'bhawani enclave': 'Sector 9',
    'a block sushant lok phase 1': 'Sector 43',
    'begampur khatola': 'Near Sector 74',
    'udyog vihar phase 1': 'Sector 18',
    'mg road': 'Spans multiple sectors along the road',
    'devilal colony': 'Sector 9',
    'ashok vihar': 'Sector 5',
    'faridabad road': 'Spans multiple sectors along the road',
    'sispal vihar': 'Sector 49',
    'surat nagar': 'Sector 104',
    'ashok vihar phase i': 'Sector 5',
    'garauli kalan': 'Sector 37',
    'rajiv colony': 'Sector 7',
    'block a surya vihar': 'Sector 9',
    'vishnu garden': 'Sector 5',
    'nars': 'No specific sector identified',
    'naharpur rupa': 'Sector 95',
    'bptp': 'Sector 37D',
    'golf course ext road': 'Spans multiple sectors along the road',
    'new palam vihar phase 2': 'Sector 110, 111',
    'sec 3 bhim vihar part 1 bhimgher kheri': 'Sector 3',
    'laxmi garden': 'Sector 10',
    'manohar nagar': 'Sector 7',
    'farukhnagar': 'Near Sector 92',
    'cyber city': 'Sector 24, 25A',
    'ghamroj': 'Near Sector 63A',
    'nirvana country pocket h': 'Sector 50',
    'iffco chowk': 'Sector 29',
    'tekchand nagar': 'Sector 5',
    'sai kunj': 'Sector 7',
    'sadar bazar': 'Sector 12',
    'shakti nagar': 'Sector 11',
    'near khandsa road': 'Spans multiple sectors along the road',
    'block h ashok vihar phase iii extension': 'Sector 5',
    'shivji park colony': 'Sector 7',
    'ravi nagar': 'Sector 5',
    'pratap nagar': 'Sector 8',
    'ram nagar': 'Sector 12',
    'near nand hospital': 'No specific sector identified',
    'new palam vihar phase 1': 'Sector 110, 111',
    'lucknow': 'Not in Gurgaon',
    'khandsa': 'Near Sector 37',
    'rajiv chowk': 'Sector 29',
    'hno 13 sagar enclave sura': 'No specific sector identified',
    'rosewood': 'Sector 49',
    'huda saraswati vihar': 'Sector 28, 43',
    'alipur': 'Near Sector 95',
    'valley view estate': 'Near Sector 52',
    'mahavir pura': 'Sector 11',
    'pataudi road': 'Spans multiple sectors along the road',
    'laxman vihar, railway road': 'Sector 3',
    'near pataudi chowk': 'Spans multiple sectors along the road',
    'gopal nagar, garhi ghasita, sonipat': 'Not in Gurgaon',
    'ravi nager basai road': 'Sector 9',
    'damdma': 'Near Sohna Road',
    'ambience island': 'Near Sector 24',
    'mahalaxmi garden, rajendra place': 'Sector 105',
    'south city': 'Spans multiple sectors',
    'new jyoti park': 'Sector 7',
    'jacobpura near sadar bazar': 'Sector 12'
}

# %% [markdown]
# ##### converting sector col from sectorName to sectorNumer, wherever not already existing

# %%
def map_sector_nums(sector_name):
        return sector_gpt.get(sector_name, sector_name)

# %%
data['sector'].str.strip().apply(map_sector_nums)
# Out:
# 0                                       sector 70
# 1                                       sector 40
# 2                                   Sector 22, 23
# 3                                       sector 69
# 4       New Gurgaon spans multiple sectors: 76-95
#                           ...
# 4077                                Sector 55, 56
# 4078                                Sector 22, 23
# 4079                                    sector 59
# 4080                              sector 36 sohna
# 4081                                    sector 15
# Name: sector, Length: 4082, dtype: object

# %%
data['sector'] = data['sector'].str.strip().apply(map_sector_nums)

# %%
data.to_csv(r'../2. data_cleaning\4.1 some cols FEed.csv', index=False)
