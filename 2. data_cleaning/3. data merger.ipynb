# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

flats_data = pd.read_csv(r'F:\Github_dsc\HousePrice_MegaProject\2. data_cleaning\0. data\cleaned_flats_data.csv')
houses_data = pd.read_csv(r'F:\Github_dsc\HousePrice_MegaProject\2. data_cleaning\0. data\cleaned_houses_data.csv')

# %%
data = pd.concat([flats_data, houses_data], ignore_index=True)

# %%
data = data.sample(data.shape[0], ignore_index=True)

# %%
data.sample(3)
# Out:
#       Unnamed: 0                                property_name  \
# 3793        1065  4 Bedroom House for sale in Nirvana Country
# 2041        1956              3 BHK Flat in Sector 77 Gurgaon
# 472         2116              2 BHK Flat in Sector 68 Gurgaon
#
#                  society  area_in_sqft  price_in_crores  price_per_sqft  \
# 3793      unitech espace        2160.0             7.42         34351.0
# 2041  emaar palm heights        2000.0             2.25         11250.0
# 472        m3m sierra 68        1220.0             1.25         10245.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 3793  Plot area 2160(200.67 sq.m.)Built Up area: 320...      4.0       4.0
# 2041             Super Built up area 2000(185.81 sq.m.)      3.0       3.0
# 472   Super Built up area 1220(113.34 sq.m.)Carpet a...      2.0       2.0
#
#      balcony additionalRoom  \
# 3793       3            NaN
# 2041       3   servant room
# 472        3  not available
#
# ...

# %%
data.drop(columns=['Unnamed: 0'], axis=1, inplace=True)

# %%
data.sample(3)
# Out:
#                                       property_name  \
# 2778  4 Bedroom House for sale in Sector 66 Gurgaon
# 3413    2 BHK Flat in Ashok Vihar Phase 3 Extension
# 1164                 2 BHK Flat in Sector 2 Gurgaon
#
#                                  society  area_in_sqft  price_in_crores  \
# 2778                  emaar mgf marbella        2250.0             8.70
# 3413                     pooja apartment         700.0             0.25
# 1164  mittal cosmos executive apartments        1145.0             0.75
#
#       price_per_sqft                                       areaWithType  \
# 2778         38667.0  Plot area 250(209.03 sq.m.)Built Up area: 267 ...
# 3413          3571.0                     Carpet area: 700 (65.03 sq.m.)
# 1164          6550.0  Super Built up area 1145(106.37 sq.m.)Built Up...
#
#       bedRoom  bathroom balcony           additionalRoom  \
# 2778      4.0       5.0       2  Study Room,Servant Room
# ...

# %%
data.shape
# Out:
# (4082, 22)

# %%
data.to_csv(r'F:\Github_dsc\HousePrice_MegaProject\2. data_cleaning\0. data\merged_flat_house_data.csv')
