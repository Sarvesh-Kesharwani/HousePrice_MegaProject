# %%
import pandas as pd

# %%
data = pd.read_csv(r'F:\Github_dsc\HousePrice_MegaProject\1. data_gathering\3. merging data\cx_data\merged_data\merged_data.csv')
print(data.shape)
data.sample(3)
# Out:
# (4123, 24)
#       Unnamed: 0                                 property_name  \
# 1471        1471              3 BHK Flat in Sector 109 Gurgaon
# 2344        2344              3 BHK Flat in Sector 107 Gurgaon
# 3323        3323  2 Bedroom House for sale in Sector 8 Gurgaon
#
#                                                    link  \
# 1471  https://www.99acres.com/3-bhk-bedroom-apartmen...
# 2344  https://www.99acres.com/3-bhk-bedroom-apartmen...
# 3323  https://www.99acres.com/2-bhk-bedroom-independ...
#
#                            society             price  \
# 1471                    ATS Kocoon         2.2 Crore
# 2344  Signature Global Solera3.7 ★            60 Lac
# 3323                           NaN  Price on Request
#
#                           area  \
# 1471           ₹ 10,501/sq.ft.
# 2344            ₹ 8,000/sq.ft.
# 3323  (74 sq.m.) Built-up Area
#
#                                            areaWithType     bedRoom  \
# ...

# %% [markdown]
# dropping `Unnamed: 0` col

# %%
data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
data.sample(3)
# Out:
#                                           property_name  \
# 2015                                3 BHK Flat in Sohna
# 3711  2 Bedroom House for sale in Ashok Vihar Phase ...
# 3649            3 Bedroom House for sale in Ashok Vihar
#
#                                                    link               society  \
# 2015  https://www.99acres.com/3-bhk-bedroom-apartmen...  Eldeco Accolade3.8 ★
# 3711  https://www.99acres.com/2-bhk-bedroom-independ...                   NaN
# 3649  https://www.99acres.com/3-bhk-bedroom-independ...                   NaN
#
#           price                  area  \
# 2015  1.1 Crore        ₹ 7,549/sq.ft.
# 3711     70 Lac  (93 sq.m.) Plot Area
# 3649     90 Lac  (84 sq.m.) Plot Area
#
#                                            areaWithType     bedRoom  \
# 2015             Super Built up area 1457(135.36 sq.m.)  3 Bedrooms
# 3711                         Plot area 111(92.81 sq.m.)  2 Bedrooms
# ...

# %% [markdown]
# # trying to clean or featureEngineer `property_name` col

# %%
data['property_name'].value_counts()
# Out:
# property_name
# 2 BHK Flat in Sohna                           126
# 3 BHK Flat in Sector 102 Gurgaon               76
# 3 BHK Flat in Sector 65 Gurgaon                57
# 3 BHK Flat in Sector 92 Gurgaon                53
# 3 BHK Flat in Sector 69 Gurgaon                51
#                                              ...
# 10 Bedroom House for sale in Ravi Nagar         1
# 6 Bedroom House for sale in Farukhnagar         1
# 9 Bedroom House for sale in Sheetla Colony      1
# 3 BHK Flat in Civil Lines                       1
# 8 Bedroom House for sale in DLF Phase 2         1
# Name: count, Length: 985, dtype: int64

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
data['property_name'].str.lower().str.strip()
# Out:
# 0                            2 bhk flat in krishna colony
# 1                               2 bhk flat in ashok vihar
# 2                                     2 bhk flat in sohna
# 3                         2 bhk flat in sector 61 gurgaon
# 4                         2 bhk flat in sector 92 gurgaon
#                               ...
# 4118                   3 bedroom house for sale in bissar
# 4119                   3 bedroom house for sale in bissar
# 4120              8 bedroom house for sale in dlf phase 2
# 4121    8 bedroom house for sale in c block sushant lo...
# 4122        2 bedroom house for sale in sector 92 gurgaon
# Name: property_name, Length: 4123, dtype: object

# %%
data.columns
# Out:
# Index(['property_name', 'link', 'society', 'price', 'area', 'areaWithType',
#        'bedRoom', 'bathroom', 'balcony', 'additionalRoom', 'address',
#        'floorNum', 'facing', 'agePossession', 'nearbyLocations', 'description',
#        'furnishDetails', 'features', 'rating', 'property_id', 'rate',
#        'property_type', 'noOfFloor'],
#       dtype='object')

# %% [markdown]
# # couldn't clean it, decided to move to work on simpler cols first.

# %%
data.columns
# Out:
# Index(['property_name', 'link', 'society', 'price', 'area', 'areaWithType',
#        'bedRoom', 'bathroom', 'balcony', 'additionalRoom', 'address',
#        'floorNum', 'facing', 'agePossession', 'nearbyLocations', 'description',
#        'furnishDetails', 'features', 'rating', 'property_id', 'rate',
#        'property_type', 'noOfFloor'],
#       dtype='object')

# %%
data.sample(5)
# Out:
#                                        property_name  \
# 522                 3 BHK Flat in Sector 104 Gurgaon
# 4062  5 Bedroom House for sale in Sector 106 Gurgaon
# 2150                2 BHK Flat in Sector 67A Gurgaon
# 4029   4 Bedroom House for sale in Sector 82 Gurgaon
# 1396                 3 BHK Flat in Sector 70 Gurgaon
#
#                                                    link  \
# 522   https://www.99acres.com/3-bhk-bedroom-apartmen...
# 4062  https://www.99acres.com/5-bhk-bedroom-independ...
# 2150  https://www.99acres.com/2-bhk-bedroom-apartmen...
# 4029  https://www.99acres.com/4-bhk-bedroom-independ...
# 1396  https://www.99acres.com/3-bhk-bedroom-apartmen...
#
#                            society       price                   area  \
# 522          Puri Emerald Bay3.7 ★  2.45 Crore        ₹ 10,000/sq.ft.
# 4062               Godrej Meridien   5.6 Crore  (372 sq.m.) Plot Area
# 2150                 Pyramid Urban      60 Lac         ₹ 8,571/sq.ft.
# ...

# %% [markdown]
# # noOfFLoors

# %%
data['noOfFloor'].shape
# Out:
# (4123,)

# %%
data['noOfFloor'].value_counts(dropna=False, normalize=True)
# Out:
# noOfFloor
# NaN          0.765462
# 3 Floors     0.074945
# 2 Floors     0.072763
# 1 Floors     0.044385
# 4 Floors     0.033713
# 5 Floors     0.002183
# 0 Floors     0.001455
# 6 Floors     0.000728
# 14 Floors    0.000728
# 11 Floors    0.000485
# 10 Floors    0.000485
# 12 Floors    0.000485
# 13 Floors    0.000243
# 27 Floors    0.000243
# 21 Floors    0.000243
# 20 Floors    0.000243
# 02 Floors    0.000243
# 41 Floors    0.000243
# 51 Floors    0.000243
# 16 Floors    0.000243
# 33 Floors    0.000243
# Name: proportion, dtype: float64

# %%
data[data['property_type']!='flat'].sample(3)
# Out:
#                                       property_name  \
# 3926  5 Bedroom House for sale in Sector 73 Gurgaon
# 3612   6 Bedroom House for sale in Sector 1 Gurgaon
# 3983  4 Bedroom House for sale in Sector 48 Gurgaon
#
#                                                    link             society  \
# 3926  https://www.99acres.com/5-bhk-bedroom-independ...         DLF Alameda
# 3612  https://www.99acres.com/6-bhk-bedroom-independ...                 NaN
# 3983  https://www.99acres.com/4-bhk-bedroom-independ...  Vipul Tatvam Villa
#
#            price                       area  \
# 3926    17 Crore      (450 sq.m.) Plot Area
# 3612  4.75 Crore  (418 sq.m.) Built-up Area
# 3983  5.75 Crore      (241 sq.m.) Plot Area
#
#                                            areaWithType     bedRoom  \
# 3926  Plot area 4842(449.84 sq.m.)Built Up area: 900...  5 Bedrooms
# 3612                 Built Up area: 4500 (418.06 sq.m.)  6 Bedrooms
# ...

# %%
data[(data['property_type']!='flat') & (data['noOfFloor'].isna())].shape
# Out:
# (128, 23)

# %% [markdown]
# # droipping property_id col since no use for now

# %%
data.drop(columns='property_id', axis=1, inplace=True)
data.sample(3)
# Out:
#                                       property_name  \
# 2989                3 BHK Flat in Sector 92 Gurgaon
# 3603  2 Bedroom House for sale in Sector 89 Gurgaon
# 2753                2 BHK Flat in Sector 76 Gurgaon
#
#                                                    link            society  \
# 2989  https://www.99acres.com/3-bhk-bedroom-apartmen...         Sare Homes
# 3603  https://www.99acres.com/2-bhk-bedroom-independ...        Greenopolis
# 2753  https://www.99acres.com/2-bhk-bedroom-apartmen...  Suncity Avenue 76
#
#        price                       area  \
# 2989  82 Lac             ₹ 5,384/sq.ft.
# 3603  70 Lac  (121 sq.m.) Built-up Area
# 2753  55 Lac             ₹ 7,422/sq.ft.
#
#                                            areaWithType     bedRoom  \
# 2989  Super Built up area 1523(141.49 sq.m.)Built Up...  3 Bedrooms
# 3603                  Built Up area: 1297 (120.5 sq.m.)  2 Bedrooms
# 2753                     Carpet area: 741 (68.84 sq.m.)  2 Bedrooms
#
# ...

# %%
data.sample(3)
# Out:
#                                        property_name  \
# 1661                 3 BHK Flat in Sector 86 Gurgaon
# 244                  3 BHK Flat in Sector 71 Gurgaon
# 3733  4 Bedroom House for sale in Sector 112 Gurgaon
#
#                                                    link  \
# 1661  https://www.99acres.com/3-bhk-bedroom-apartmen...
# 244   https://www.99acres.com/3-bhk-bedroom-apartmen...
# 3733  https://www.99acres.com/4-bhk-bedroom-independ...
#
#                           society       price                       area  \
# 1661  DLF New Town Heights 24.0 ★  1.28 Crore             ₹ 8,205/sq.ft.
# 244            CHD Avenue 713.6 ★     1 Crore             ₹ 6,734/sq.ft.
# 3733     Experion Windchants3.8 ★  7.46 Crore  (590 sq.m.) Built-up Area
#
#                                            areaWithType     bedRoom  \
# 1661  Super Built up area 1930(179.3 sq.m.)Carpet ar...  3 Bedrooms
# 244              Super Built up area 1485(137.96 sq.m.)  3 Bedrooms
# ...

# %% [markdown]
# # working on bedroom, bathroom, balcony cols

# %%
data['bedRoom'].str.strip().str.lower().fillna('').value_counts(dropna=False)
# Out:
# bedRoom
# 3 bedrooms     1590
# 2 bedrooms     1039
# 4 bedrooms      721
# 5 bedrooms      229
# 1 bedroom       143
#                 127
# 6 bedrooms       85
# 9 bedrooms       45
# 8 bedrooms       34
# 7 bedrooms       32
# 12 bedrooms      29
# 10 bedrooms      21
# 16 bedrooms      12
# 13 bedrooms       4
# 19 bedrooms       2
# 18 bedrooms       2
# 11 bedrooms       2
# 21 bedrooms       1
# bedroom           1
# 36 bedrooms       1
# 34 bedrooms       1
# 14 bedrooms       1
# 20 bedrooms       1
# Name: count, dtype: int64

# %%
data['bedRoom']=data['bedRoom'].str.strip().str.lower().fillna('')

# %%
data[data['bedRoom'].str.contains('[^\D]+' ,regex=True)]
# Out:
#                                       property_name  \
# 0                      2 BHK Flat in Krishna Colony
# 1                         2 BHK Flat in Ashok Vihar
# 2                               2 BHK Flat in Sohna
# 3                   2 BHK Flat in Sector 61 Gurgaon
# 4                   2 BHK Flat in Sector 92 Gurgaon
# ...                                             ...
# 4114  4 Bedroom House for sale in Sector 26 Gurgaon
# 4115        3 Bedroom House for sale in DLF Phase 2
# 4116  3 Bedroom House for sale in Sector 26 Gurgaon
# 4117  3 Bedroom House for sale in Sector 26 Gurgaon
# 4118             3 Bedroom House for sale in Bissar
#
#                                                    link  \
# 0     https://www.99acres.com/2-bhk-bedroom-apartmen...
# 1     https://www.99acres.com/2-bhk-bedroom-apartmen...
# 2     https://www.99acres.com/2-bhk-bedroom-apartmen...
# 3     https://www.99acres.com/2-bhk-bedroom-apartmen...
# ...

# %% [markdown]
# regex method i cound't make work, so decided to try manual layman approach

# %%
data['bedRoom'].value_counts(dropna=False)
# Out:
# bedRoom
# 3 bedrooms     1590
# 2 bedrooms     1039
# 4 bedrooms      721
# 5 bedrooms      229
# 1 bedroom       143
#                 127
# 6 bedrooms       85
# 9 bedrooms       45
# 8 bedrooms       34
# 7 bedrooms       32
# 12 bedrooms      29
# 10 bedrooms      21
# 16 bedrooms      12
# 13 bedrooms       4
# 19 bedrooms       2
# 18 bedrooms       2
# 11 bedrooms       2
# 21 bedrooms       1
# bedroom           1
# 36 bedrooms       1
# 34 bedrooms       1
# 14 bedrooms       1
# 20 bedrooms       1
# Name: count, dtype: int64

# %%
data['bedRoom'] = data['bedRoom'].str.split(' ').str[0]
data['bedRoom']
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 4118    3
# 4119
# 4120
# 4121
# 4122
# Name: bedRoom, Length: 4123, dtype: object

# %%
data['bedRoom'].value_counts()
# Out:
# bedRoom
# 3          1590
# 2          1039
# 4           721
# 5           229
# 1           143
#             127
# 6            85
# 9            45
# 8            34
# 7            32
# 12           29
# 10           21
# 16           12
# 13            4
# 19            2
# 18            2
# 11            2
# 21            1
# bedroom       1
# 36            1
# 34            1
# 14            1
# 20            1
# Name: count, dtype: int64

# %%
data[data['bedRoom'].str.contains('bedroom')]
# Out:
#      property_name  link  society  price  area  areaWithType  bedRoom  \
# 286  property_name  link  society  price  area  areaWithType  bedroom
#
#      bathroom  balcony  additionalRoom  address  floorNum  facing  \
# 286  bathroom  balcony  additionalRoom  address  floorNum  facing
#
#      agePossession  nearbyLocations  description  furnishDetails  features  \
# 286  agePossession  nearbyLocations  description  furnishDetails  features
#
#      rating rate property_type noOfFloor
# 286  rating  NaN          flat       NaN

# %%
data['bedRoom'].replace('bedroom', '', inplace=True)

# %%
data['bedRoom'].value_counts()
# Out:
# bedRoom
# 3     1590
# 2     1039
# 4      721
# 5      229
# 1      143
#        128
# 6       85
# 9       45
# 8       34
# 7       32
# 12      29
# 10      21
# 16      12
# 13       4
# 18       2
# 19       2
# 11       2
# 20       1
# 21       1
# 36       1
# 34       1
# 14       1
# Name: count, dtype: int64

# %%
data.sample(3)
# Out:
#                                  property_name  \
# 1395           2 BHK Flat in Sector 86 Gurgaon
# 3755  4 Bedroom House for sale in South City 1
# 1264           2 BHK Flat in Sector 85 Gurgaon
#
#                                                    link  \
# 1395  https://www.99acres.com/2-bhk-bedroom-apartmen...
# 3755  https://www.99acres.com/4-bhk-bedroom-independ...
# 1264  https://www.99acres.com/2-bhk-bedroom-apartmen...
#
#                     society       price                   area  \
# 1395  Pyramid Urban Homes 2      43 Lac         ₹ 8,582/sq.ft.
# 3755                    NaN    11 Crore  (301 sq.m.) Plot Area
# 1264       SS The Leaf3.8 ★  1.05 Crore         ₹ 6,402/sq.ft.
#
#                                 areaWithType bedRoom     bathroom  \
# 1395          Carpet area: 501 (46.54 sq.m.)       2  2 Bathrooms
# 3755             Plot area 360(301.01 sq.m.)       4  4 Bathrooms
# 1264  Super Built up area 1640(152.36 sq.m.)       2  2 Bathrooms
#
# ...

# %%
data['bathroom'].value_counts(dropna=False)
# Out:
# bathroom
# 2 Bathrooms     1165
# 3 Bathrooms     1158
# 4 Bathrooms      872
# 5 Bathrooms      309
# 1 Bathroom       182
# 6 Bathrooms      128
# NaN              127
# 7 Bathrooms       44
# 9 Bathrooms       42
# 8 Bathrooms       30
# 12 Bathrooms      23
# 10 Bathrooms      11
# 16 Bathrooms       8
# 13 Bathrooms       4
# 18 Bathrooms       4
# 11 Bathrooms       4
# 20 Bathrooms       3
# 17 Bathrooms       3
# 14 Bathrooms       2
# 21 Bathrooms       1
# bathroom           1
# 36 Bathrooms       1
# 34 Bathrooms       1
# Name: count, dtype: int64

# %%
data['bathroom'] = data['bathroom'].str.strip().str.split(' ').str[0]

# %%
data['bathroom'].value_counts()
# Out:
# bathroom
# 2           1165
# 3           1158
# 4            872
# 5            309
# 1            182
# 6            128
# 7             44
# 9             42
# 8             30
# 12            23
# 10            11
# 16             8
# 18             4
# 11             4
# 13             4
# 17             3
# 20             3
# 14             2
# 21             1
# bathroom       1
# 36             1
# 34             1
# Name: count, dtype: int64

# %%
data['bathroom'].replace('bathroom', '', inplace=True)

# %%
data['bathroom'].value_counts(dropna=False)
# Out:
# bathroom
# 2      1165
# 3      1158
# 4       872
# 5       309
# 1       182
# 6       128
# NaN     127
# 7        44
# 9        42
# 8        30
# 12       23
# 10       11
# 16        8
# 13        4
# 18        4
# 11        4
# 20        3
# 17        3
# 14        2
# 21        1
#           1
# 36        1
# 34        1
# Name: count, dtype: int64

# %%
data['bathroom'].fillna('', inplace=True)

# %%
data['bathroom'].value_counts(dropna=False)
# Out:
# bathroom
# 2     1165
# 3     1158
# 4      872
# 5      309
# 1      182
# 6      128
#        128
# 7       44
# 9       42
# 8       30
# 12      23
# 10      11
# 16       8
# 18       4
# 11       4
# 13       4
# 17       3
# 20       3
# 14       2
# 21       1
# 36       1
# 34       1
# Name: count, dtype: int64

# %%
data.to_csv(r'F:\Github_dsc\HousePrice_MegaProject\2. data_cleaning\data\cleaned_level1.csv')
